# %%
import pandas as pd
lusitania='/Users/russellsasaki/Desktop/DSI/dsi_workspace/projects/project-02/assets/lusitania.csv'
lusitania_df=pd.read_csv(lusitania)
lusitania_df.head()
# Out:
#   Family name Title Personal name   Fate Age Department/Class Passenger/Crew  \
# 0     CAMERON   Mr.    Charles W.   Lost  38             Band           Crew
# 1  CARR-JONES   Mr.            E.   Lost  37             Band           Crew
# 2   DRAKEFORD   Mr.        Edward  Saved  30             Band           Crew
# 3     HAWKINS   Mr.        Handel  Saved  25             Band           Crew
# 4   HEMINGWAY   Mr.  John William  Saved  27             Band           Crew
#
#   Citizenship     Position Status  ...  Country Lifeboat Rescue Vessel  \
# 0     British          NaN    NaN  ...      NaN      NaN           NaN
# 1     British          NaN    NaN  ...      NaN      NaN           NaN
# 2     British       Violin    NaN  ...      NaN      NaN           NaN
# 3     British        Cello    NaN  ...      NaN      NaN           NaN
# 4     British  Double Bass    NaN  ...      NaN      NaN           NaN
#
# ...

# %%
lusitania_df['Age'].unique()
# Out:
# array(['38', '37', '30', '25', '27', '48', nan, '24', '19 ?', '57', '50',
#        '56', '41', '19', '33', '29', '18', '20', '21', '26', '17', '58',
#        '47', '54', '35', '43', '59', '53', '44', '51', '40', '49', '42',
#        '32', '31', '34', '22', '45', '36', '29 ?', '52', '23', '60', '28',
#        '16', '46', '15', '39', '63 ?', '55', '64', '53 ?', '09-months',
#        '6', '9', '14', '10', '12', '?', '62', '5', '8', '65', '68', '76',
#        '61', '63', '03-months', '1.5', '2.5', '18-months', '3', '2',
#        '25 ?', '08-months', '4', '15-months', '14-months', 'Infant',
#        '3-6-months ?', '51 or 47', '45 or 51', '22 (?)', '17-months',
#        '13-months', '02-months', '49 ?', '05-months', '11', '59 (64?)',
#        '63 (51?)', '37 (39?)', '32 (22?)', '31 (32?)', '24 (23?)', '27?',
#        '7', '42?', '31 ?', '10-months', '38 (?)', '70', '62 (?)',
#        '06-months', '13', '2_', '11-months', '30 ?', '34?', '1',
# ...

# %%
df=pd.DataFrame(lusitania_df, columns=['Age'])
df.describe()
# Out:
#          Age
# count   1308
# unique   120
# top       30
# freq      62

# %%
print len(lusitania_df[lusitania_df['Title']=='Mr.'])
print len(lusitania_df[lusitania_df['Title']=='Dr.'])
print len(lusitania_df[lusitania_df['Title']=='Master'])
print len(lusitania_df[lusitania_df['Title']=='Reverend'])
print len(lusitania_df[lusitania_df['Title']=='Mrs.'])
print len(lusitania_df[lusitania_df['Title']=='Miss'])
# Out:
# 1038
# 11
# 96
# 7
# 277
# 238

# %%
print len(lusitania_df[lusitania_df['Fate']=='Saved'])
# Out:
# 763

# %%
df['months age']=df['Age'].str.replace('(\d\d-......)', '1')
df
df['real age'] = df['months age'].str.extract('(\d\d?)', expand=True)
df
# Out:
#        Age months age real age
# 0       38         38       38
# 1       37         37       37
# 2       30         30       30
# 3       25         25       25
# 4       27         27       27
# 5       48         48       48
# 6      NaN        NaN      NaN
# 7      NaN        NaN      NaN
# 8       24         24       24
# 9     19 ?       19 ?       19
# 10      57         57       57
# 11      50         50       50
# 12     NaN        NaN      NaN
# 13     NaN        NaN      NaN
# 14     NaN        NaN      NaN
# 15     NaN        NaN      NaN
# 16     NaN        NaN      NaN
# 17     NaN        NaN      NaN
# 18     NaN        NaN      NaN
# 19     NaN        NaN      NaN
# 20     NaN        NaN      NaN
# 21     NaN        NaN      NaN
# 22     NaN        NaN      NaN
# 23      25         25       25
# 24     NaN        NaN      NaN
# 25      56         56       56
# 26     NaN        NaN      NaN
# 27      41         41       41
# 28     NaN        NaN      NaN
# ...

# %%
df=df.convert_objects(convert_numeric=True)
df=df.dropna()
# Out:
# /Users/russellsasaki/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
